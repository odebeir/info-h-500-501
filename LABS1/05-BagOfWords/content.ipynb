# %% [markdown]
# # LAB 5 - Bag of Words
#
# **Objectives:**
#
# * Using corner detectors and patch descriptors
# * Implement face recognition using Bag of Words

# %% [markdown]
# ## Extracting descriptors from an image
#
# We will reuse the face images from the "Eigenfaces" lab. The images are availabe here: [faces_tp_info_h_501.zip](http://homepages.ulb.ac.be/~odebeir/data/faces_tp_info_h_501.zip)
#
# Documentation:
# * http://scikit-image.org/docs/dev/api/skimage.feature.html
#
#
# 1. Extract FAST corners from an image
# 2. Extract BRIEF descriptors for those corners

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import os

files = ['normal/'+f for f in os.listdir('normal')]
# Load entire dataset in memory
dataset = np.zeros((len(files),200,170)) # create empty dataset
for idx,f in enumerate(files):
    im = plt.imread(f)
    if( len(im.shape) > 2 ):
        im = im[:,:,0] # for the RGBA images : take only the 1st channel
    
    dataset[idx,:,:] = im

# Show the first image
plt.figure()
plt.gray()
plt.imshow(dataset[0])
plt.show()

# %%
# -- Your code here -- #

# %% [markdown]
# ## Building Bag of Words vocabulary
#
# 1. Select a random sample of face images
# 2. Build an array with all BRIEF descriptors extracted from those images
# 3. Using the [KMeans algorithm](http://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html), create a "vocabulary" from the descriptors

# %%
# -- Your code here -- #

# %% [markdown]
# ## Word histogram and face recognition
#
# 1. For all images in the dataset, compute the "words" histogram (i.e. the frequency of each word in the image).
# 2. Create a function which, for a given face image, finds the closest histogram in the dataset (excluding itself).

# %%
# -- Your code here -- #
