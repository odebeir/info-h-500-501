# %% [markdown]
# # LAB 1 - plate detection
#
# **objectives:**
#
# * resolve an applied problem related to road traffic image analysis
# * image enhancement
# * object detection
# * object segmentation and recognition

# %% [markdown]
# ## Car lights and plate detection
#
# 1. import all the images are contained into [cars.zip](http://homepages.ulb.ac.be/~odebeir/data/cars.zip)
# 2. write a program that automatically detect cars lights and plate for night images (bounding box + centroid) (night images)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

from skimage.feature import hog
from skimage import data, color, exposure
from skimage.io import imread
import numpy as np

image = imread('night1.pgm')

plt.figure(figsize=[20,15])
plt.imshow(image)
plt.colorbar();

# %% [markdown]
# ## Car detection (texture based)
#
# 1. compute [histogram of oriented gradient](http://scikit-image.org/docs/dev/api/skimage.feature.html#hog) for day images
# 2. detect part of the image occupied by a vehicle

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

from skimage.feature import hog
from skimage import data, color, exposure
from skimage.io import imread
import numpy as np

image = imread('day1.ppm')

fd, hog_image = hog(image, orientations=8, pixels_per_cell=(64, 64),
                    cells_per_block=(1, 1), visualise=True)

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(20,25), sharex=True, sharey=True)

ax1.axis('off')
ax1.imshow(image, cmap=plt.cm.gray)
ax1.set_title('Input image')
ax1.set_adjustable('box-forced')

# Rescale histogram for better display
hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 5))

ax2.axis('off')
ax2.imshow(hog_image_rescaled, cmap=plt.cm.gray)
ax2.set_title('Histogram of Oriented Gradients')
ax1.set_adjustable('box-forced')
plt.show()

# %% [markdown]
# ## Plate enhancement, character segmentation and recognition
#
# 1. write a program that segment character from background for the images in the plates folder
# 2. segment each separate character
# 3. extract descriptors for each feature
# 4. propose a method to recognize each character automatically

# %%
ima = (imread('327254586.pgm').sum(axis=2)/3).astype(np.uint8)
plt.imshow(ima,cmap=plt.cm.gray)
plt.colorbar();
